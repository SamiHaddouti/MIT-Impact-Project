# %%
import json

candidates_path = "data/candidates.json"
with open(candidates_path, 'r') as file:
    data = json.load(file)

data
# Out:
# [['TiO2', 'LiCO3'],
#  ['LiH', 'TiCl4'],
#  ['Ti(OH)4', 'Li2CO3'],
#  ['K2CO3', 'TiO2', 'LiNO3'],
#  ['P2O5', 'Nb2O5'],
#  ['Na2CO3', 'NbCl5'],
#  ['H3PO4', 'Nb(OH)3'],
#  ['TiO2', 'LiNO3', 'Li', 'H2O', 'NiOH', 'Ni(OH)2'],
#  ['Li2CO3', 'LiCO3', 'O2', 'TiO2', 'Ni(OH)2'],
#  ['K2CO3', 'Ni(NO3)2', 'Ti(OH)4', 'LiOH', 'H2O'],
#  ['TiO2', 'NiO', 'Li2O', 'O2'],
#  ['CaCO3', 'Fe2O3'],
#  ['Fe(NO3)3', 'Ca(NO3)2'],
#  ['Ca(OH)2', 'Fe(OH)3'],
#  ['FeCl3', 'CaCl2'],
#  ['SrCO3', 'Pr(NO3)3', 'Co3O4'],
#  ['SrCO3', 'Pr6O11', 'Co3O4'],
#  ['Co(NO3)2', 'Sr(NO3)2', 'Pr(NO3)3'],
#  ['Gd2O3', 'SrCO3', 'Co3O4'],
#  ['Co(NO3)2', 'Sr(NO3)2', 'Gd(NO3)3'],
#  ['Co(OH)2', 'Gd2O3', 'SrCO3'],
#  ['SrCO3', 'Gd(OH)3', 'Co3O4'],
#  ['TiO2', 'LiCO3'],
#  ['LiH', 'TiCl4'],
#  ['Ti(OH)4', 'Li2CO3'],
#  ['K2CO3', 'TiO2', 'LiNO3'],
#  ['MnCO3', 'LiH'],
#  ['Li2CO3', 'Mn3O4'],
#  ['Mn(NO3)2', 'LiNO3'],
#  ['Mn(OH)2', 'LiOH'],
#  ['TiO2', 'LiCO3'],
#  ['LiH', 'TiCl4'],
#  ['Li2SO4', 'TiO2'],
#  ['Ti(OH)4', 'LiNO3'],
#  ['TiO2', 'LiCO3'],
#  ['LiH', 'TiCl4'],
#  ['Ti(OH)4', 'Li2CO3'],
#  ['K2CO3', 'TiO2', 'LiNO3'],
#  ['MnCO3', 'LiH'],
#  ['Li2CO3', 'Mn3O4'],
#  ['Mn(NO3)2', 'LiNO3'],
#  ['Mn(OH)2', 'LiOH'],
#  ['Ni(NO3)2', 'LiH'],
#  ['NiCO3', 'MnCO3', 'Li2CO3'],
#  ['Mn(OH)2', 'Ni(OH)2', 'LiNO3'],
#  ['Mn2O3', 'NiO', 'Li2O'],
#  ['Sm3(PO4)3', 'SrCO3'],
#  ['Sm(NO3)3', 'Sr(NO3)2'],
#  ['Sr(OH)2', 'Sm(OH)3'],
#  ['Ba(Mg(NO3)2)2', 'Eu(NO3)3', 'B2O3'],
#  ['B2O3', 'Eu2O3', 'BaCO3', 'MgO'],
#  ['Eu(OH)3', 'Mg(OH)2', 'Ba(H2BO3)2'],
#  ['B2O3', 'Eu(NO3)3', 'Ba(NO3)2', 'Mg(NO3)2'],
#  ['TiO2', 'LiCO3'],
#  ['LiH', 'TiCl4'],
#  ['Ti(OH)4', 'Li2CO3'],
#  ['K2CO3', 'TiO2', 'LiNO3'],
#  ['LiCO3', 'SiO2', 'Fe2O3'],
#  ['Fe1H3K3', 'SiO2', 'LiH'],
#  ['Fe2SiO4', 'Li2SiO3'],
#  ['Fe(NO3)3', 'Si(OH)4', 'LiNO3'],
#  ['Na2CO3', 'TiO2'],
#  ['Na2SiO3', 'TiCl4'],
#  ['NaNO3', 'Ti(NO3)3'],
#  ['TiO2', 'K2CO3'],
#  ['Ti(OC(CH3)3)4', 'KOH'],
#  ['Ti(OH)4', 'KH2PO4'],
#  ['K2CO3', 'TiCl4'],
#  ['Cs2CO3', 'TiO2'],
#  ['Cs2CO3', 'TiF4'],
#  ['Ti(OH)4', 'Cs2CO3'],
#  ['Na2CO3', 'TiO2'],
#  ['Na2SiO3', 'TiCl4'],
#  ['NaOH', 'TiSO4'],
#  ['Mn(NO3)2', 'LiCO3'],
#  ['LiOH', 'Mn3O4'],
#  ['Li2SO4', 'MnCO3'],
#  ['MnO2', 'LiNO3'],
#  ['Mn(NO3)2', 'LiCO3'],
#  ['Mn(OH)2', 'LiOH'],
#  ['Li2SO4', 'MnSO4'],
#  ['Mn3O4', 'LiNO3'],
#  ['Mn(NO3)2', 'LiCO3'],
#  ['Mn(OH)2', 'LiOH'],
#  ['Li2SO4', 'MnSO4'],
#  ['Mn3O4', 'LiNO3'],
#  ['BaCO3', 'SnO2', 'La2O3'],
#  ['SnCl4', 'Ba(NO3)2', 'La(NO3)3'],
#  ['Ba(OH)2', 'Sn(OH)4', 'La(OH)3'],
#  ['Ba(NO3)2', 'La(NO3)3', 'Sn(OH)4'],
#  ['MnCO3', 'Ce(NO3)3', 'Fe2O3'],
#  ['Mn3O4', 'Fe2O3', 'CeO2'],
#  ['MnCO3', 'Ce(OH)3', 'Fe(OH)3'],
#  ['Ce(OH)3', 'Mn3O4', 'Fe(NO3)3H18'],
#  ['Fe(NO3)3.9H2O', 'Y2O3'],
#  ['Fe2O3', 'YCO3.2H2O'],
#  ['Fe(OH)3', 'YF3'],
#  ['SnO', 'Nb2O5', 'Y2O3'],
#  ['Na2CO3', 'SnCl4', 'NbCl5'],
#  ['K2CO3', 'Nb(OH)3', 'Sn(NO3)2'],
#  ['Li2CO3', 'SnO2', 'Nb2O5'],
#  ['TiO2', 'SrCO3'],
#  ['TiN', 'Sr(NO3)2'],
#  ['Sr(OH)2', 'Ti(OH)4'],
#  ['SrCl2', 'TiCl4'],
#  ['TiO2', 'SrCO3'],
#  ['TiN', 'Sr(NO3)2'],
#  ['Sr(OH)2', 'Ti(OH)4'],
#  ['SrCl2', 'TiCl4'],
#  ['K2CO3', 'RhCl3', 'TiO2', 'SrCO3'],
#  ['Ti(OH)4', 'KOH', 'Sr(NO3)2', 'RhCl3'],
#  ['Sr(OH)2', 'RhCl3', 'TiO2', 'K2CO3'],
#  ['Sr(OH)2', 'RhCl3', 'K2CO3', 'TiCl4'],
#  ['TiO2', 'SrCO3'],
#  ['TiN', 'Sr(NO3)2'],
#  ['Sr(OH)2', 'Ti(OH)4'],
#  ['SrCl2', 'TiCl4'],
#  ['BiCl3', 'CaCO3', 'CaCl2', 'NaCl'],
#  ['Bi2O3', 'Ca(NO3)2', 'NaCl'],
#  ['BiCl3', 'Ca(OH)2', 'NaOH', 'HCl'],
#  ['CaO', 'Bi2O3', 'HCl', 'NaCl'],
#  ['Fe2O3', 'ZnO'],
#  ['Zn(NO3)2', 'Fe(NO3)3'],
#  ['Zn(CH3COO)2', 'Fe(C5H7O2)3'],
#  ['ZnCO3', 'Fe(OH)3'],
#  ['Cu(NO3)2.3H2O', 'Nb2O5'],
#  ['CuO', 'Nb2O5'],
#  ['Cu(NO3)2', 'K2CO3', 'Nb2O5'],
#  ['Cu(OH)2', 'Nb2O5'],
#  ['Na2CO3', 'Bi(NO3)3', 'Sr(NO3)2', 'Nb2O5'],
#  ['Bi2O3', 'Na2Nb2O7', 'SrCO3', 'Nb2O5'],
#  ['Na2CO3', 'Bi(NO3)3', 'Sr(NO3)2', 'NaNbO3'],
#  ['Na2CO3', 'Bi2O3', 'Na2Nb2O7', 'SrCO3'],
#  ['H3BO3', 'Yb2O3', 'NaH2BO3'],
#  ['H3BO3', 'Yb2O3', 'CdCO3', 'NaH2BO3'],
#  ['Cd(OH)2', 'H3BO3', 'Yb2O3', 'NaH2BO3'],
#  ['H3BO3', 'NaH2BO3'],
#  ['MnCO3', 'LiH'],
#  ['Mn(NO3)2', 'Li2CO3'],
#  ['Mn3O4', 'LiNO3'],
#  ['Mn(OH)2', 'LiOH'],
#  ['TiO2', 'LiCO3'],
#  ['LiH', 'TiCl4'],
#  ['Ti(OH)4', 'Li2CO3'],
#  ['K2CO3', 'TiO2', 'LiNO3'],
#  ['Sr(OH)', 'La(OH)'],
#  ['Al2O3', 'SrCO3'],
#  ['Sr(OH)2', 'Al(NO3)3'],
#  ['Al2O3Cl2', 'SrCl2'],
#  ['Al2O3', 'Sr(NO3)2'],
#  ['Al2O3', 'SrCO3'],
#  ['Sr(OH)2', 'Al(NO3)3'],
#  ['AlON', 'Sr(NO3)2'],
#  ['Al2O3', 'SrCO3'],
#  ['Sr(OH)2', 'Al(NO3)3.9H2O'],
#  ['Al2O3', 'SrCl2'],
#  ['BaCO3', 'Fe2O3'],
#  ['Ba(NO3)2', 'Fe(NO3)3'],
#  ['Fe3O4', 'Ba(OH)2'],
#  ['Ba(CH3COO)2', 'Fe(OH)3'],
#  ['KCl', 'Nb2O5'],
#  ['K2CO3', 'Nb2O5'],
#  ['KH2PO4', 'Nb2O5'],
#  ['NbF5', 'K2SiF6'],
#  ['KCl', 'Nb2O5'],
#  ['K2CO3', 'Nb2O5'],
#  ['KH2PO4', 'Nb2O5'],
#  ['K2La2O7', 'Nb2O5'],
#  ['RbCO3', 'Ta2O5', 'Ca(NO3)2', 'K2CO3'],
#  ['Rb2Ta2O7', 'CaCO3'],
#  ['Rb2CO3', 'TaCl5', 'Ca(NO3)2'],
#  ['Rb2Ta2O7', 'CaO'],
#  ['LiCO3', 'Ta2O5'],
#  ['LiOH', 'Ta(OH)5'],
#  ['LiF', 'TaF5'],
#  ['LiNO3', 'Ta(NO3)5'],
#  ['Na2CO3', 'Ta2O5'],
#  ['NaOH', 'Na5TaO3(NO3)10'],
#  ['Na2SiO3', 'TaCl5'],
#  ['NaNO3', 'Ta2O5'],
#  ['KCl', 'Ta2O5'],
#  ['K2CO3', 'Ta2O5'],
#  ['O17', 'KH2', 'KHTa6O17', 'Ta6', 'H2O'],
#  ['K2TaF7', 'H2O2'],
#  ['TiO2', 'KCl', 'K2Ti4O9', 'La2O3'],
#  ['Ti(OH)4', 'K2CO3', 'La(NO3)3'],
#  ['K2Ti6O13', 'TiO2', 'K2CO3', 'La2O3'],
#  ['K2Ti6O13', 'Ti(OH)4', 'K2CO3', 'La(NO3)3'],
#  ['CuO', 'CuCl'],
#  ['HCl', 'CuCO'],
#  ['CuCl', 'NaCl'],
#  ['HCl', 'CuI'],
#  ['Na2CO3', 'Mn2O3'],
#  ['NaOH', 'Mn(CH3COO)3'],
#  ['MnO', 'Na2O2'],
#  ['NaNO3', 'MnCO3'],
#  ['SnO2', 'Zn(NO3)2.6H2O'],
#  ['SnCl4', 'ZnCO3'],
#  ['Sn(OH)4', 'ZnO'],
#  ['SnCl4', 'Zn(OH)2'],
#  ['Na2CO3', 'Ta2O5'],
#  ['NaOH', 'Na5TaO3(NO3)10'],
#  ['Na2SiO3', 'TaCl5'],
#  ['NaNO3', 'Ta2O5'],
#  ['MoO3', 'ZnO'],
#  ['H2MoO4', 'Zn(OH)2'],
#  ['ZrOCl2', 'LiCO3'],
#  ['Li2CO3', 'ZrO2'],
#  ['LiH', 'ZrO2'],
#  ['ZrOCl2', 'Li2O'],
#  ['Ga2O3', 'Zn(NO3)2.6H2O'],
#  ['Ga2O3', 'ZnO'],
#  ['Ga(NO3)3', 'Zn(OH)2'],
#  ['Ga2O3', 'ZnCO3'],
#  ['ZrOCl2', 'LiCO3'],
#  ['LiH', 'ZrO2'],
#  ['ZrSiO4', 'Li2SO4'],
#  ['ZrO(NO3)2', 'LiNO3'],
#  ['ZrOCl2', 'LiCO3'],
#  ['Li2CO3', 'ZrO2'],
#  ['LiH', 'ZrO2'],
#  ['ZrOCl2', 'Li2O'],
#  ['Co(NO3)2', 'MnCO3', 'K2CO3'],
#  ['Co(OH)2', 'Mn3O4'],
#  ['Mn(Ac)2', 'Co(Ac)2'],
#  ['MnCO3', 'Co(OH)2', 'Y2O3'],
#  ['Fe(NO3)3.9H2O', 'CuCO3.Cu(OH)2'],
#  ['CuO', 'Fe2O3'],
#  ['Cu(NO3)2.6H2O', 'Fe(OH)3'],
#  ['FeCl3.6H2O', 'Cu(OAc)2.H2O'],
#  ['MnCO3', 'LiH'],
#  ['Li2CO3', 'Mn3O4'],
#  ['Mn(NO3)2', 'LiNO3'],
#  ['Mn(OH)2', 'LiOH'],
#  ['KH2PO4', 'Na2CO3', 'NH4VO3', 'NaF'],
#  ['K2HPO4', 'NaVO3', 'NH4F', 'NaF'],
#  ['NH4F', 'Na4V10O28', 'NaF'],
#  ['NaVO3', 'NH4F', 'K3PO4', 'NaF'],
#  ['Al2O3', 'LiCO3'],
#  ['Al(NO3)3', 'LiH'],
#  ['Al(OH)3', 'LiNO3'],
#  ['Al2O3', 'LiF', 'NaF'],
#  ['Ga2O3', 'Zn(NO3)2.6H2O'],
#  ['Ga2O3', 'ZnO'],
#  ['Ga(NO3)3', 'Zn(OH)2'],
#  ['Ga2O3', 'ZnCO3'],
#  ['LiCO3', 'SiO2', 'Fe2O3'],
#  ['Fe1H3K3', 'SiO2', 'LiH'],
#  ['Fe2SiO4', 'Li2SiO3'],
#  ['Fe(NO3)3', 'Si(OH)4', 'LiNO3'],
#  ['Co3O4', 'Ba(NO3)2', 'K2CO3', 'La2O3'],
#  ['BaCO3', 'Ba(OH)2', 'Co3O4', 'La2O3'],
#  ['Co(NO3)2', 'K2CO3', 'Ba(OH)2', 'La(NO3)3'],
#  ['Co3O4', 'Ba(OH)2', 'Y2O3', 'La2O3'],
#  ['Na2CO3', 'TiO2'],
#  ['Na2SiO3', 'TiCl4'],
#  ['NaOH', 'TiSO4'],
#  ['Na2CO3', 'TiO2'],
#  ['NaCl', 'TiCl4'],
#  ['Na2SiO3', 'TiO2'],
#  ['BaCO3', 'MnCO3', 'Nd(NO3)3'],
#  ['BaCO3', 'Nd2O3', 'Mn3O4'],
#  ['Mn(OH)2', 'Nd(OH)3', 'Ba(OH)2'],
#  ['BaCO3', 'MnCO3', 'Nd2O3', 'Y2O3'],
#  ['NaNO3', 'NH4H2PO4'],
#  ['NaPO3', 'V2O5'],
#  ['Na2CO3', 'VOPO4'],
#  ['V2P2O7', 'NaOH'],
#  ['Na2CO3', 'NH4VO3'],
#  ['Li2MnO3', 'LiCO3', 'Co3O4'],
#  ['Mn2O3', 'Li2O', 'Co3O4'],
#  ['Co(NO3)2', 'LiHCO3', 'Mn(NO3)2'],
#  ['Li2O2', 'Mn3O4', 'Co3O4'],
#  ['MnCO3', 'LiCO3', 'Ni(NO3)2.6H2O'],
#  ['Ni(OH)2', 'Mn3O4'],
#  ['Mn2O3', 'NiO2', 'LiNO3'],
#  ['MnO2', 'Li2SO4'],
#  ['TiO2', 'SrCO3'],
#  ['TiN', 'Sr(NO3)2'],
#  ['Sr(OH)2', 'Ti(OH)4'],
#  ['SrCl2', 'TiCl4'],
#  ['GeO2', 'Mg(NO3)2.6H2O'],
#  ['Mg(OH)2', 'GeSe2'],
#  ['Mg(OH)2', 'Se'],
#  ['GeSe2', 'Mg(SeO3)2'],
#  ['GeO2', 'Zn(NO3)2.6H2O'],
#  ['GeO2', 'ZnCO3'],
#  ['Ge(OH)4', 'ZnO'],
#  ['GeO2', 'Zn(OH)2'],
#  ['TiO2', 'Nb2O5'],
#  ['Ti(OH)4', 'Nb2O5'],
#  ['Nb2O5', 'TiCl4'],
#  ['Nb2O5', 'Ti(OC(O)CH3)4', 'Nb(OC(O)CH3)5', 'TiO2'],
#  ['TiN', 'Nb2O5', 'NbN', 'TiO2'],
#  ['Nb2O3', 'TiN', 'Nb2O5', 'TiO2'],
#  ['TiN', 'LiNO3', 'Nb2O5', 'TiO2'],
#  ['CaCO3', 'Nb2O5'],
#  ['Ca(NO3)2', 'Nb2O5'],
#  ['Ca(OH)2', 'Nb2O5'],
#  ['Ca(NO3)2', 'Na2NbO5'],
#  ['Fe1(NO3)3H18', 'LiCO3', 'P2O5'],
#  ['NH4H2PO4', 'Fe2O3', 'LiHCO4'],
#  ['LiOH', 'FePO4', 'LiNO3'],
#  ['Fe2(SO4)3', 'Li2CO3'],
#  ['CaCO3', 'Nb2O5'],
#  ['Ca(NO3)2', 'Nb2O5'],
#  ['Ca(OH)2', 'Nb2O5'],
#  ['Ca(NO3)2', 'Na2NbO5'],
#  ['CaCO3', 'NH4H2PO4'],
#  ['Ca(NO3)2.4H2O', 'CaHPO4.2H2O'],
#  ['CaO', 'H3PO4'],
#  ['CaCl2', 'NH4H2PO4'],
#  ['Ca(OH)2', 'CaCO3', 'Mg(NO3)2', 'Mg(NO3)2.6H2O'],
#  ['CaHPO4.2H2O', 'CaO', 'CaHPO4', 'MgCO3'],
#  ['MgCO3', 'MgO', 'Ca3(PO4)2'],
#  ['Mg(H2PO4)2', 'Ca(NO3)2', 'Ca(NO3)2.4H2O', 'CaO', 'Mg(H2PO4)2.7H2O'],
#  ['Bi(NO3)3', 'KCl', 'SeO2', 'BaCl2'],
#  ['SeO2', 'Bi2O3', 'KCl', 'NH4Cl'],
#  ['Bi(NO3)3', 'K2SO4', 'SeO2', 'NaCl'],
#  ['Bi2Se3', 'KCl', 'NaCl', 'HCl'],
#  ['K2WO4', 'SnO2', 'Na2WO4', 'Te', 'Na2CO3', 'WO3'],
#  ['K2WO4', 'Na2Te', 'SnO2', 'WO3'],
#  ['K2WO4', 'SnO2', 'Na2TeO3', 'WO3'],
#  ['K2WO4', 'SnO2', 'Na2TeO4', 'WO3'],
#  ['Ni(NO3)2', 'LiH'],
#  ['Li2CO3', 'NiO'],
#  ['Ni(OH)2', 'LiNO3'],
#  ['Ni(OAc)2', 'LiOH'],
#  ['BaCO3', 'MoO3', 'H3BO3', 'Nb2O5'],
#  ['MoO3', 'K2CO3', 'Ba(NO3)2', 'Nb2O5'],
#  ['MoO3', 'Ba(NO3)2', 'Nb2O5', 'Y2O3'],
#  ['MoO3', 'Ba(NO3)2', 'Nb2O5', 'La2O3'],
#  ['H3BO3', 'Cs2CO3', 'Ba(NO3)2', 'Ta2O5'],
#  ['BaCO3', 'Cs2CO3', 'TaCl5', 'H2O'],
#  ['Cs2CO3', 'Ba(NO3)2', 'KCl', 'Ta2O5'],
#  ['Cs2CO3', 'Ba(NO3)2', 'Ta2O5', 'Li2CO3'],
#  ['WO3', 'K2CO3', 'ZrO(NO3)2'],
#  ['ZrOCl2', 'WOCl4', 'Na2CO3'],
#  ['H3BO3', 'WO3', 'ZrO2'],
#  ['Na2SiO3', 'WO3', 'Zr(OH)4'],
#  ['Bi(NO3)3', 'V2O5'],
#  ['NH4VO3', 'Bi2O3'],
#  ['Bi(OH)3', 'V2O5'],
#  ['Al2O3', 'Nd(NO3)3'],
#  ['Al2O3', 'Nd2O3'],
#  ['Al(NO3)3', 'Nd(OH)3'],
#  ['Al2O3', 'NdCO3'],
#  ['NaOH', 'NaCl'],
#  ['Fe(NO3)3', 'SrCO3'],
#  ['Sr(OH)2', 'FePO4'],
#  ['Sr(NO3)2', 'FePO4'],
#  ['Fe(OH)', 'Sr(OH)', 'Cr(OH)', 'O'],
#  ['Fe2O3', 'SrCO3'],
#  ['Fe(NO3)3', 'Sr(NO3)2'],
#  ['Sr(OH)2', 'Fe(OH)3'],
#  ['SrCl2', 'FeCl3'],
#  ['MnCO3', 'LiH'],
#  ['Mn(NO3)2', 'Li2CO3'],
#  ['Mn3O4', 'LiNO3'],
#  ['Mn(OH)2', 'LiOH'],
#  ['Ca(NO3)2', 'CaCO3', 'NH4H2PO4', 'FePO4', 'Fe2(PO4)3'],
#  ['CaCO3', 'Fe2O3', 'CaHPO4'],
#  ['Fe(NO3)3', 'Ca(NO3)2'],
#  ['CaCO3', 'P2O5', 'FePO4'],
#  ['K2CO3', 'Sr(NO3)2', 'NaNbO3', 'Nb2O5', 'Bi(NO3)3'],
#  ['B2O3', 'Nb2O5', 'Bi2O3', 'NaNbO2', 'SrCO3'],
#  ['Nb2O5', 'Y2O3', 'Bi(NO3)3', 'NaNbO2', 'SrCO3'],
#  ['Nb2O5', 'Bi(NO3)3', 'NaNbO2', 'SrCO3', 'La2O3'],
#  ['Bi(NO3)3', 'CaCO3', 'NaNbO3', 'Nb2O5'],
#  ['Bi2O3', 'NaNbO2', 'Nb2O5', 'CaCO3'],
#  ['Na3NbO6', 'Ca(NO3)2', 'Nb2O5', 'Bi(NO3)3'],
#  ['Bi2O3', 'Nb2O5', 'NaNbO3', 'CaCO3'],
#  ['Co(NO3)2', 'LiH'],
#  ['CoO', 'Li2CO3'],
#  ['Co(OH)2', 'LiNO3'],
#  ['CoCl2', 'LiOH'],
#  ['TiO2', 'LiOH'],
#  ['Ti(OH)4', 'Li2CO3'],
#  ['Ti(NO3)4', 'LiNO3'],
#  ['TiOS2', 'Li2SiO3'],
#  ['MnO2', 'KCl'],
#  ['KMnO4', 'V2O5'],
#  ['VOSO4', 'K2CO3'],
#  ['MnCO3', 'LiH'],
#  ['Mn(NO3)2', 'Li2CO3'],
#  ['Mn3O4', 'LiNO3'],
#  ['Mn(OH)2', 'LiOH'],
#  ['LiCO3', 'Mn3O4'],
#  ['Mn(NO3)2', 'LiOH'],
#  ['Mn2O3', 'Li2CO3'],
#  ['MnCO3', 'LiNO3'],
#  ['CaCO3', 'Nb2O5'],
#  ['Ca(NO3)2', 'Nb2O5'],
#  ['Ca(OH)2', 'Nb2O5'],
#  ['Ca(NO3)2', 'Na2NbO5'],
#  ['BaCO3', 'Mn3O4', 'Y2O3'],
#  ['Mn2O3', 'Ba(NO3)2', 'Y(NO3)3'],
#  ['Mn2O3', 'Ba(OH)2', 'YF3'],
#  ['Ba(CH3COO)2', 'Y(CH3COO)3', 'Mn(CH3COO)2'],
#  ['Cu(NO3)2.3H2O', 'S', 'GeO2', 'ZnO'],
#  ['GeS2', 'ZnS', 'CuI'],
#  ['GeS2', 'ZnS', 'Cu2S'],
#  ['GeCl4', 'CuCl2', 'ZnCl2', 'S'],
#  ['AgNO3', 'GeO2', 'ZnS', 'S'],
#  ['GeO2', 'S', 'ZnS', 'Ag2CO3'],
#  ['GeS2', 'AgI', 'ZnS', 'S'],
#  ['GeO2', 'Ag2SO4', 'S', 'ZnO'],
#  ['AgNO3', 'S', 'TeO2', 'FeS'],
#  ['S', 'Fe(NO3)3', 'Ag2S'],
#  ['Ag2Te', 'TeO2', 'FeS2', 'S'],
#  ['FeS2', 'Ag2TeO3', 'S'],
#  ['Fe2S3', 'AgNO3', 'TeO2'],
#  ['S', 'Fe2Te3', 'Ag2S'],
#  ['Ag2Te', 'FeS2', 'S'],
#  ['TeO2', 'FeS', 'Ag2Te3'],
#  ['Cu(NO3)2.3H2O', 'La(NO3)3', 'Mn(NO3)2.4H2O'],
#  ['CuO', 'Mn2O3', 'La2O3'],
#  ['Mn(OH)2', 'Cu(OH)2', 'La(OH)3'],
#  ['MnCO3', 'La(CO3)3', 'CuCO3.5H2O'],
#  ['LiH', 'FePO4'],
#  ['Li2CO3', 'Fe2O3'],
#  ['Fe(NO3)3', 'LiNO3'],
#  ['LiOH', 'FePO4.2H2O'],
#  ['LiH', 'FePO4'],
#  ['Li2CO3', 'Fe2O3'],
#  ['Fe(NO3)3', 'LiNO3'],
#  ['LiOH', 'FePO4.2H2O'],
#  ['Bi(NO3)3', 'Ti(OH)4'],
#  ['Bi2O3', 'TiO2'],
#  ['Bi(OC(CH3)3)3', 'TiCl4'],
#  ['K2CO3', 'Fe2(SO4)3', 'V2O5', 'MnCO3'],
#  ['Fe(NO3)3', 'KCl', 'Mn(NO3)2', 'NH4VO3'],
#  ['K2CO3', 'Mn(OH)2', 'V2O5', 'Fe3O4'],
#  ['Li2CO3', 'V2O5', 'MnO2', 'Fe2O3'],
#  ['BaCO3', 'CaCO3', 'Y(NO3)3', 'Co3O4'],
#  ['BaCO3', 'CaCO3', 'Co3O4', 'Y2O3'],
#  ['Co(NO3)2', 'Ba(NO3)2', 'Y(NO3)3', 'Ca(NO3)2'],
#  ['BaCO3', 'CaCO3', 'Co3O4', 'Y2O3'],
#  ['CaCO3', 'Y(NO3)3'],
#  ['Ca(NO3)2', 'Y2O3'],
#  ['CaHF2', 'YF3'],
#  ['CaO', 'YCl3'],
#  ['Ba(OH)', 'Y(OH)', 'Ca(OH)'],
#  ['BaCO3', 'CaCO3'],
#  ['Ba(NO3)2', 'Ca(NO3)2'],
#  ['Ca(OH)2', 'Ba(OH)2'],
#  ['BaCO3', 'Ca(OH)2'],
#  ['NaNO3', 'V2O5'],
#  ['Na2CO3', 'NH4VO3'],
#  ['VOSO4', 'NaOH'],
#  ['NaVO3', 'CaCO3'],
#  ['GeO2', 'B2O3', 'H3BO3', 'Ba(GeO4)2', 'BaCO3'],
#  ['Ba(NO3)2', 'Ge(OH)4', 'Ba(GeO4)2', 'B2O3'],
#  ['GeO2', 'Ba(NO3)2', 'B2O3', 'Ba3Ge2O9'],
#  ['H3BO3', 'GeO2', 'B2O3', 'Ba(OH)2'],
#  ['MnCO3', 'LiH'],
#  ['Mn(NO3)2', 'Li2CO3'],
#  ['Mn3O4', 'LiNO3'],
#  ['Mn(OH)2', 'LiOH'],
#  ['MnCO3', 'LiCO3', 'Ni(OH)2'],
#  ['Mn3O4', 'NiO', 'LiNO3'],
#  ['NiSO4', 'Li2SO4', 'MnSO4'],
#  ['Mn(OH)2', 'Ni(OH)2', 'LiOH'],
#  ['TiO2', 'Mn(NO3)2.9H2O'],
#  ['MnCO3', 'TiO2'],
#  ['Mn(OH)2', 'Ti(OH)4'],
#  ['Mn(NO3)2.9H2O', 'SnO2'],
#  ['SnCl4', 'MnCO3'],
#  ['Mn(OH)2', 'Sn(OH)4'],
#  ['MnO', 'SnO'],
#  ['Na2SeO3', 'V2O5'],
#  ['Bi2O3', 'Se'],
#  ['K2SeO4', 'V2O5'],
#  ['Bi(NO3)3', 'H2SeO3'],
#  ['Al2O3', 'Mg(NO3)2.6H2O', 'NH4OH'],
#  ['AlN', 'Al2O3', 'NH4OH', 'MgCO3'],
#  ['Mg(OH)2', 'AlN', 'Al2O3', 'NH4Cl'],
#  ['Al2O3', 'Li3N', 'AlN', 'MgO'],
#  ['Fe(NO3)3', 'TiO2'],
#  ['TiO2', 'Fe2O3'],
#  ['TiO2', 'FeCO3'],
#  ['Ti(OH)4', 'Fe(OH)3'],
#  ['Pb(NO3)2', 'ZnO'],
#  ['Zn(NO3)2', 'PbCO3'],
#  ['Zn(OH)2', 'PbO'],
#  ['ZnCO3', 'Pb(OH)2'],
#  ['RbCO3', 'Rb2O', 'Ca(NO3)2', 'Nb2O5'],
#  ['H3BO3', 'Rb2CO3', 'CaCO3', 'Nb2O5'],
#  ['Rb2CO3', 'Ca(NO3)2', 'Nb2O5', 'Y2O3'],
#  ['Rb2CO3', 'Ca(NO3)2', 'Nb2O5', 'La2O3'],
#  ['LiCO3', 'Nb2O5', 'La2O3'],
#  ['La(NO3)3', 'LiNO3', 'Nb2O5'],
#  ['LiF', 'LaF3', 'NbF5'],
#  ['LiOH', 'Nb2O5', 'La(OH)3'],
#  ['Na2CO3', 'NH4Nb2O7', 'La(NO3)3'],
#  ['La(C2O4)3', 'NH4HNbO4', 'NaOH', 'H2O'],
#  ['Al2O3', 'CaCO3'],
#  ['Ca(NO3)2.4H2O', 'Al(NO3)3.9H2O'],
#  ['AlCl3', 'CaCl2'],
#  ['Ca(OH)2', 'Al(OH)3'],
#  ['Al2O3', 'CaCO3'],
#  ['Ca(NO3)2.4H2O', 'Al(NO3)3.9H2O'],
#  ['AlCl3', 'CaCl2'],
#  ['CaO', 'Al2O3'],
#  ['K2CO3', 'V2O5'],
#  ['NH4VO3', 'KOH'],
#  ['KNO3', 'V4O7'],
#  ['VCl5', 'KCl'],
#  ['KClO3', 'V2O5'],
#  ['K2CO3', 'V2O5'],
#  ['KHCO3', 'V2O5'],
#  ['KNO3', 'V2O5'],
#  ['Cs2CO3', 'V2O5'],
#  ['V2O3', 'Cs2O'],
#  ['CsNO3', 'V2O5'],
#  ['Cs2CO3', 'Li2CO3', 'K2CO3', 'V2O5'],
#  ['Cs2CO3', 'V2O5'],
#  ['NH4VO3', 'CsNO3'],
#  ['CsOH', 'V2O5'],
#  ['Cs2CO3', 'V2O5'],
#  ['Cu(NO3)2.3H2O', 'Ga2O3'],
#  ['CuO', 'Ga2S3'],
#  ['CuCl2', 'GaCl3', 'S'],
#  ['Ga2S3', 'I2', 'CuI'],
#  ['In(NO3)3', 'Cu(CH3COO)2.3H2O', 'Na2S', 'S'],
#  ['Na2S', 'CuCl2', 'InCl3', 'S'],
#  ['In2O3', 'S', 'Cu(OH)2', 'H2S'],
#  ['In2S3', 'CuI', 'S'],
#  ['MnCO3', 'KHCO4'],
#  ['MnO2', 'KOH'],
#  ['Mn(OH)2', 'K2SO4'],
#  ['Y(NO3)3', 'SnO2'],
#  ['SnCl4', 'Y2O3'],
#  ['Sn(OH)4', 'Y(OH)3'],
#  ['Sn(OH)2', 'Y2O3'],
#  ['Ti(OC(CH3)3)4', 'Cs2CO3'],
#  ['Cs2CO3', 'TiO2'],
#  ['Ti(OH)4', 'Cs2CO3'],
#  ['Ti(NO3)4', 'Cs2CO3'],
#  ['Ga2O3', 'La(NO3)3'],
#  ['Ga2O3', 'La(OH)3'],
#  ['Ga2O3', 'LaCO3'],
#  ['Ga(NO3)3', 'La(NO3)3'],
#  ['Sb2O3', 'Ga2O3', 'La(NO3)3', 'La2O3'],
#  ['Ga2O3', 'O2', 'S', 'LaCO3'],
#  ['La(OH)3', 'O2', 'S', 'GaCl3'],
#  ['Ga2O3', 'S', 'LaGaO3', 'La2O3'],
#  ['Sb2O3', 'Ga2O3', 'La(NO3)3', 'Na2SO4'],
#  ['Ga2O3', 'S', 'NaCl', 'La2O3'],
#  ['K2CO3', 'Ga2O3', 'LaCO3'],
#  ['CaCO3', 'Ga2O3', 'La(OH)3'],
#  ['Fe(NO3)3', 'K2CO3'],
#  ['Fe2O3', 'K2Ti4O9'],
#  ['K2Ti6O13', 'Fe(OH)3'],
#  ['Fe(NO3)3', 'K2Ti4O9', 'TiO2'],
#  ['Cs2CO3', 'TiO2'],
#  ['Ti(OH)4', 'Cs2CO3'],
#  ['Ti(NO3)4', 'Cs2CO3'],
#  ['Cs2CO3', 'TiOCl2'],
#  ['Fe(NO3)3', 'LiH'],
#  ['Li2CO3', 'Fe2O3'],
#  ['K2CO3', 'FePO4', 'LiNO3'],
#  ['FeCl3', 'LiOH'],
#  ['MnCO3', 'Y(NO3)3'],
#  ['Mn3O4', 'Y2O3'],
#  ['Mn(NO3)2', 'Y(OH)3'],
#  ['MnCO3', 'YF3'],
#  ['Na2CO3', 'SiO2'],
#  ['NaOH', 'SiO2'],
#  ['Co(NO3)3', 'Fe(NO3)3', 'SrCO3'],
#  ['Fe(C5H7O2)3', 'Sr(C6H5O7)2', 'Co(C5H7O2)3'],
#  ['Co2O3', 'Fe2O3', 'SrO'],
#  ['Sr(OH)2', 'Co(OH)3', 'Fe(OH)3'],
#  ['Na2CO3', 'Ta2O5'],
#  ['NaOH', 'Na5TaO3(NO3)10'],
#  ['Na2SiO3', 'TaCl5'],
#  ['NaNO3', 'Ta2O5'],
#  ['Sb2O3', 'HCl', 'H2O2'],
#  ['K2CO3', 'Sb2O3', 'KCl', 'MnCO3'],
#  ['BaCO3', 'SbCl3', 'K2CO3'],
#  ['K2SO4', 'MnO2', 'Sb2O3', 'KCl'],
#  ['Fe2O3', 'La(NO3)3'],
#  ['FeCO3', 'La2O3'],
#  ['FeCl3', 'La(OH)3'],
#  ['Fe(OH)3', 'La(NO3)3'],
#  ['Co(NO3)2.6H2O', 'La(NO3)3'],
#  ['CoO', 'La2O3'],
#  ['Co(OH)2', 'La(OH)3'],
#  ['Co3O4', 'LaCO3'],
#  ['Cr2O3', 'La(NO3)3'],
#  ['CrO3', 'La2O3'],
#  ['Cr(NO3)3', 'La(OH)3'],
#  ['Cr2(SO4)3', 'LaCO3'],
#  ['NiO', 'La(NO3)3'],
#  ['Ni(NO2)2', 'La2O3'],
#  ['Ni(OAc)2', 'La(OH)3'],
#  ['Ni(OH)2', 'La(OH)3'],
#  ['SiO2', 'La(NO3)3'],
#  ['SiO2', 'La2O3'],
#  ['SiO2', 'La(OH)3'],
#  ['TiO2', 'SrCO3'],
#  ['TiN', 'Sr(NO3)2'],
#  ['Sr(OH)2', 'Ti(OH)4'],
#  ['SrCl2', 'TiCl4'],
#  ['TiO2', 'LiCO3'],
#  ['LiH', 'TiCl4'],
#  ['Ti(OH)4', 'Li2CO3'],
#  ['K2CO3', 'TiO2', 'LiNO3'],
#  ['LiH', 'V2O5'],
#  ['NH4VO3', 'Li2CO3'],
#  ['LiNO3', 'V2O5'],
#  ['LiOH', 'V2O5'],
#  ['MoO3', 'Th(NO3)4'],
#  ['Th(OH)3', 'MoO3'],
#  ['Sm(NO3)3', 'SrCO3', 'Co3O4'],
#  ['Sm2O3', 'SrCO3', 'Co3O4'],
#  ['Sr(Ac)2', 'Sm(Ac)3', 'Co(Ac)2'],
#  ['Y2O3', 'BaO', 'Sm2O3', 'SrCO3', 'Co3O4'],
#  ['Mg(NO3)2', 'Fe2O3'],
#  ['Fe(NO3)3', 'MgCO3'],
#  ['Fe(OH)3', 'MgO'],
#  ['Fe3O4', 'Mg(OH)2'],
#  ['NiO', 'Fe2O3'],
#  ['Ni(NO3)2', 'Fe(NO3)3'],
#  ['Fe(OH)3', 'Ni(OH)2'],
#  ['Fe(CH3COO)3', 'Ni(CH3COO)2'],
#  ['Mn2O3', 'Sr(NO3)2', 'Pd2O3', 'Fe2O3', 'La(NO3)3', 'SrCO3', 'La2O3'],
#  ['La(NO3)3', 'Sr(NO3)2', 'Fe2O3', 'Mn(NO3)2', 'Pd(NO3)2'],
#  ['FeCO3', 'La2CO3', 'PdCO3', 'MnCO3', 'SrCO3'],
#  ['Mn2O3', 'La(OH)3', 'PdO', 'Fe2O3', 'SrCO3', 'La2O3'],
#  ['LiCO3', 'MoO3', 'V2O5'],
#  ['MoO3', 'LiNO3', 'V2O5'],
#  ['LiHCO4', 'MoO3', 'V2O5'],
#  ['V2O5', 'Li2MoO4'],
#  ['Sb2O3', 'SrCO3', 'Y2O3'],
#  ['Sb2O3', 'Y(NO3)3', 'Sr(NO3)2'],
#  ['SrH2PO4', 'Y2(SO4)3', 'Sb2O3'],
#  ['Sr(OH)2', 'SbCl3', 'YF3'],
#  ['MnCO3', 'LiH'],
#  ['Li2CO3', 'Mn3O4'],
#  ['Mn(NO3)2', 'LiNO3'],
#  ['Mn(OH)2', 'LiOH'],
#  ['Mn2O3', 'LiCO3', 'Co3O4'],
#  ['Co(NO3)2.6H2O', 'Mn2O3', 'Li2CO3', 'LiNO3'],
#  ['Mn3O4', 'Li2CO3', 'Co(OH)2', 'LiNO3'],
#  ['Mn(OH)2', 'Li2CO3', 'LiNO3', 'Co3O4'],
#  ['LiCO3', 'SiO2', 'Fe2O3'],
#  ['Fe1H3K3', 'SiO2', 'LiH'],
#  ['Fe2SiO4', 'Li2SiO3'],
#  ['Fe(NO3)3', 'Si(OH)4', 'LiNO3'],
#  ['ZrO2', 'Tb2O3', 'Y2O3'],
#  ['Tb(NO3)3.5H2O', 'Y(NO3)3.7H2O', 'ZrO2'],
#  ['YCl3.7H2O', 'TbCl3.7H2O', 'ZrO2'],
#  ['Tb2CO3', 'Y2CO3', 'ZrO2'],
#  ['LiH', 'V2O5'],
#  ['LiCO3', 'V2O5'],
#  ['Na3PO4', 'LiNO3', 'V2O5'],
#  ['LiF', 'V2O5'],
#  ['MnCO3', 'LiH'],
#  ['Li2CO3', 'Mn3O4'],
#  ['Mn(NO3)2', 'LiNO3'],
#  ['Mn(OH)2', 'LiOH'],
#  ['CaO', 'CoC2O4.H2O', 'Fe(NO3)3.9H2O', 'SrCO3'],
#  ['CoO', 'Fe2O3', 'SrCO3', 'Y2O3'],
#  ['Sr(OH)2', 'Co(CH3COO)2.H2O', 'CaCO3', 'FeCl3.7H2O'],
#  ['CaO', 'Fe(NO3)3.9H2O', 'Co(NO3)2.6H2O', 'Sr(NO3)2'],
#  ['CaCO3', 'CoO'],
#  ['Ca(NO3)2.4H2O', 'Co(NO3)2.6H2O'],
#  ['Ca(OH)2', 'CoO'],
#  ['CaCl2', 'Co(CH3COO)2.4H2O'],
#  ['Bi(NO3)3', 'TiO2'],
#  ['Bi2O3', 'TiO2', 'B2O3'],
#  ['Bi(NO3)3', 'Ti(OH)4'],
#  ['Na2CO3', 'Ti(OH)4', 'Bi2O3'],
#  ['Mg(OH)2', 'SiO2'],
#  ['Si', 'MgCO3'],
#  ['SiH4', 'MgCl2'],
#  ['Si(OCH3)4', 'Mg(NO3)2'],
#  ['MnCO3', 'LiCO3', 'Ni(OH)2'],
#  ['Mn3O4', 'NiO', 'LiNO3'],
#  ['NiSO4', 'Li2SO4', 'MnSO4'],
#  ['Mn(OH)2', 'Ni(OH)2', 'LiOH'],
#  ['Ni(NO3)2', 'LiH'],
#  ['NiCO3', 'MnCO3', 'Li2CO3'],
#  ['Mn(OH)2', 'Ni(OH)2', 'LiNO3'],
#  ['Mn2O3', 'NiO', 'Li2O'],
#  ['Y(NO3)3', 'Ga2O3', 'Y2O3', 'Sb2O3'],
#  ['Ga(NO3)3', 'Sb2O3', 'YCl3', 'Y2O3'],
#  ['H3BO3', 'Sb2O3', 'Ga2O3', 'Y(OH)3'],
#  ['Ga(NO3)3', 'Sb2O3', 'NH4F', 'Y(OH)3'],
#  ['Yb2O3', 'Sb2O3', 'Y(NO3)3', 'Y2O3'],
#  ['Sb2O3', 'Yb2O3', 'YCl3', 'Y2O3'],
#  ['Sb2O3', 'Yb2O3', 'Y(OH)3', 'Y2O3'],
#  ['Sb2O3', 'Yb2O3', 'La2O3', 'Y2O3'],
#  ['Bi(NO3)3', 'K2CO3', 'In2O3', 'Ta2O5'],
#  ['Bi2O3', 'Li2CO3', 'In2O3', 'Ta2O5'],
#  ['In(NO3)3', 'Bi(NO3)3', 'NaCl', 'Ta(NO3)5'],
#  ['Na2CO3', 'Bi2O3', 'In2O3', 'Ta2O5'],
#  ['Fe(NO3)3.9H2O', 'Bi(NO3)3.5H2O'],
#  ['Bi2O3', 'Fe2O3'],
#  ['Fe(OH)3', 'Bi(OH)3'],
#  ['K2CO3', 'Bi(NO3)3.5H2O'],
#  ['LiH', 'FePO4'],
#  ['Li2CO3', 'Fe2O3'],
#  ['Fe(NO3)3', 'LiNO3'],
#  ['LiOH', 'FePO4.2H2O'],
#  ['K2CO3', 'Fe2O3'],
#  ['Fe(NO3)3', 'KOH'],
#  ['KH2PO4', 'Fe(OH)3'],
#  ['FeCl3', 'K2SiF6'],
#  ['Fe(NO3)3', 'K2CO3'],
#  ['K2CO3', 'Fe2O3'],
#  ['Fe(OH)3', 'KOH'],
#  ['K2CO3', 'FeCO3'],
#  ['Mg(NO3)2.6H2O', 'SiO2'],
#  ['SiO2', 'MgCO3'],
#  ['SiO2', 'MgO'],
#  ['SiCl4', 'Mg(OH)2'],
#  ['Al2O3', 'Na2CO3', 'Mg(NO3)2', 'SiO2'],
#  ['B2O3', 'Al2O3', 'MgO', 'SiO2'],
#  ['CaCO3', 'Al2O3', 'MgCO3', 'SiO2'],
#  ['Al(OH)3', 'K2CO3', 'Mg(OH)2', 'SiO2'],
#  ['LiH', 'V2O5'],
#  ['NH4VO3', 'Li2CO3'],
#  ['LiNO3', 'V2O5'],
#  ['LiOH', 'V2O5'],
#  ['LiH', 'V2O5'],
#  ['Li2CO3', 'V2O5'],
#  ['LiNO3', 'V2O5'],
#  ['NH4VO3', 'LiOH'],
#  ['TiO2', 'SrCO3'],
#  ['TiN', 'Sr(NO3)2'],
#  ['Sr(OH)2', 'Ti(OH)4'],
#  ['SrCl2', 'TiCl4'],
#  ['Fe2O3', 'SrCO3'],
#  ['Fe(NO3)3', 'Sr(NO3)2'],
#  ['Sr(OH)2', 'Fe(OH)3'],
#  ['SrC2O4', 'Fe2C2O4'],
#  ['Co(OH)2', 'LiCO3', 'MnCO3', 'Ni(OH)2'],
#  ['Mn2O3', 'NiO', 'LiNO3', 'Co3O4'],
#  ['Mn2O3', 'NiO', 'Li2O', 'Co3O4'],
#  ['Mn(OH)2', 'Ni(OH)2', 'Co(OH)2', 'LiOH'],
#  ['Co(NO3)2', 'LiH'],
#  ['CoO', 'Li2CO3'],
#  ['Co(OH)2', 'LiNO3'],
#  ['CoCl2', 'LiOH'],
#  ['Fe1(NO3)3H18', 'Na2CO3'],
#  ['NaOH', 'Fe2O3'],
#  ['Na2CO3', 'FeCl3'],
#  ['Fe(OH)3', 'KOH'],
#  ['TiO2', 'SrCO3'],
#  ['TiN', 'Sr(NO3)2'],
#  ['Sr(OH)2', 'Ti(OH)4'],
#  ['SrCl2', 'TiCl4'],
#  ['K2CO3', 'RhCl3', 'TiO2', 'SrCO3'],
#  ['Ti(OH)4', 'KOH', 'Sr(NO3)2', 'RhCl3'],
#  ['Sr(OH)2', 'RhCl3', 'TiO2', 'K2CO3'],
#  ['Sr(OH)2', 'RhCl3', 'K2CO3', 'TiCl4'],
#  ['TiO2', 'SrCO3'],
#  ['TiN', 'Sr(NO3)2'],
#  ['Sr(OH)2', 'Ti(OH)4'],
#  ['SrCl2', 'TiCl4'],
#  ['GeO2', 'Zn(NO3)2.6H2O'],
#  ['GeO2', 'ZnCO3'],
#  ['Ge(OH)4', 'ZnO'],
#  ['GeO2', 'Zn(OH)2'],
#  ['BaCO3', 'Fe2O3'],
#  ['Ba(NO3)2', 'Fe(NO3)3'],
#  ['Fe3O4', 'Ba(OH)2'],
#  ['Ba(CH3COO)2', 'Fe(OH)3'],
#  ['Al2O3', 'LiCO3'],
#  ['Al(NO3)3', 'LiH'],
#  ['Al(OH)3', 'LiNO3'],
#  ['Al2O3', 'LiF', 'NaF'],
#  ['BaCO3', 'CoO', 'Y(NO3)3', 'Co3O4'],
#  ['BaCO3', 'Co3O4', 'Co(NO3)2', 'Y2O3'],
#  ['Co(NO3)2', 'Ba(NO3)2', 'Y(NO3)3', 'Co3O4'],
#  ['BaCO3', 'Co2O3', 'CoO', 'Y2O3'],
#  ['TiO2', 'Mg(NO3)2.6H2O'],
#  ['TiO2', 'MgCO3'],
#  ['Ti(OH)4', 'MgO'],
#  ['Mg(OH)2', 'TiCl4'],
#  ['TiO2', 'LiCO3', 'MgO'],
#  ['Ti(OH)4', 'Mg(NO3)2', 'LiH'],
#  ['Li2SO4', 'TiO2', 'MgCO3'],
#  ['Mg(OH)2', 'LiNO3', 'TiCl4'],
#  ['Sb2O3', 'Fe2O3', 'SrCO3', 'SO3'],
#  ['Sb2O3', 'Fe(NO3)3', 'Sr(NO3)2', 'Na2SO4'],
#  ['Sr(OH)2', 'Sb2O5', 'Fe(OH)3', 'H2SO4'],
#  ['Fe(CH3COO)3', 'Sr(CH3COO)2', 'Sb2O3'],
#  ['MnCO3', 'LiH'],
#  ['Mn(NO3)2', 'Li2CO3'],
#  ['Mn3O4', 'LiNO3'],
#  ['Mn(OH)2', 'LiOH'],
#  ['Ga2O3', 'Zn(NO3)2.6H2O'],
#  ['Ga2O3', 'ZnO'],
#  ['Ga(NO3)3', 'Zn(OH)2'],
#  ['Ga2O3', 'ZnCO3'],
#  ['CaCO3', 'KCl', 'K2NbO5', 'Nb2O5'],
#  ['K2CO3', 'Ca(NO3)2', 'Nb2O5'],
#  ['H3PO4', 'CaCO3', 'KH2PO4', 'Nb2O5'],
#  ['LiNbO3', 'K2CO3', 'Ca(NO3)2', 'Nb2O5'],
#  ['Fe(NO3)3.9H2O', 'Y2O3'],
#  ['Fe2O3', 'YCO3.2H2O'],
#  ['Fe(OH)3', 'YF3'],
#  ['Li2CO3', 'LiH', 'MoO3', 'V2O5'],
#  ['LiVO3', 'V2O5', 'Li2MoO4'],
#  ['LiVO4', 'V2O5', 'LiMoO4'],
#  ['V2O5', 'LiVO2', 'Li2MoO4'],
#  ['LiCO3', 'SiO2', 'Fe2O3'],
#  ['Fe1H3K3', 'SiO2', 'LiH'],
#  ['Fe2SiO4', 'Li2SiO3'],
#  ['Fe(NO3)3', 'Si(OH)4', 'LiNO3'],
#  ['Na2CO3', 'TiO2'],
#  ['Na2SiO3', 'TiCl4'],
#  ['NaOH', 'TiSO4'],
#  ['Na2CO3', 'TiO2'],
#  ['NaCl', 'TiCl4'],
#  ['Na2SiO3', 'TiO2'],
#  ['Fe2O3', 'ZnO'],
#  ['Zn(NO3)2', 'Fe(NO3)3'],
#  ['Zn(CH3COO)2', 'Fe(C5H7O2)3'],
#  ['ZnCO3', 'Fe(OH)3'],
#  ['Ga2O3', 'Zn(NO3)2.6H2O'],
#  ['Ga2O3', 'ZnO'],
#  ['Ga(NO3)3', 'Zn(OH)2'],
#  ['Ga2O3', 'ZnCO3'],
#  ['Na2CO3', 'NH4VO3'],
#  ['TiO2', 'LiCO3'],
#  ['LiH', 'TiCl4'],
#  ['Ti(OH)4', 'Li2CO3'],
#  ['K2CO3', 'TiO2', 'LiNO3'],
#  ['TiO2', 'SrCO3'],
#  ['TiN', 'Sr(NO3)2'],
#  ['Sr(OH)2', 'Ti(OH)4'],
#  ['SrCl2', 'TiCl4'],
#  ['Cu(NO3)2.3H2O', 'Nb2O5'],
#  ['CuO', 'Nb2O5'],
#  ['Cu(NO3)2', 'K2CO3', 'Nb2O5'],
#  ['Cu(OH)2', 'Nb2O5'],
#  ['ZrOCl2', 'LiCO3'],
#  ['Li2CO3', 'ZrO2'],
#  ['LiH', 'ZrO2'],
#  ['ZrOCl2', 'Li2O'],
#  ['NaH2PO4', 'LiH'],
#  ['NH4H2PO4', 'LiOH'],
#  ['H3PO4', 'Li2CO3'],
#  ['LiH', 'FePO4'],
#  ['Li2CO3', 'Fe2O3'],
#  ['Fe(NO3)3', 'LiNO3'],
#  ['LiOH', 'FePO4.2H2O'],
#  ['ZrOCl2', 'LiCO3'],
#  ['LiH', 'ZrO2'],
#  ['ZrSiO4', 'Li2SO4'],
#  ['ZrO(NO3)2', 'LiNO3'],
#  ['ZrOCl2', 'LiCO3'],
#  ['Li2CO3', 'ZrO2'],
#  ['LiH', 'ZrO2'],
#  ['ZrOCl2', 'Li2O'],
#  ['GeO2', 'Mg(NO3)2.6H2O'],
#  ['Mg(OH)2', 'GeSe2'],
#  ['Mg(OH)2', 'Se'],
#  ['GeSe2', 'Mg(SeO3)2'],
#  ['SnO', 'Nb2O5', 'Y2O3'],
#  ['Na2CO3', 'SnCl4', 'NbCl5'],
#  ['K2CO3', 'Nb(OH)3', 'Sn(NO3)2'],
#  ['Li2CO3', 'SnO2', 'Nb2O5'],
#  ['TiO2', 'Nb2O5'],
#  ['Ti(OH)4', 'Nb2O5'],
#  ['Nb2O5', 'TiCl4'],
#  ['Nb2O5', 'Ti(OC(O)CH3)4', 'Nb(OC(O)CH3)5', 'TiO2'],
#  ['TiN', 'Nb2O5', 'NbN', 'TiO2'],
#  ['Nb2O3', 'TiN', 'Nb2O5', 'TiO2'],
#  ['TiN', 'LiNO3', 'Nb2O5', 'TiO2'],
#  ['MnCO3', 'LiH'],
#  ['Li2CO3', 'Mn3O4'],
#  ['Mn(NO3)2', 'LiNO3'],
#  ['Mn(OH)2', 'LiOH'],
#  ['Co3O4', 'Ba(NO3)2', 'K2CO3', 'La2O3'],
#  ['BaCO3', 'Ba(OH)2', 'Co3O4', 'La2O3'],
#  ['Co(NO3)2', 'K2CO3', 'Ba(OH)2', 'La(NO3)3'],
#  ['Co3O4', 'Ba(OH)2', 'Y2O3', 'La2O3'],
#  ['LiH', 'O'],
#  ['BaCO3', 'MnCO3', 'Nd(NO3)3'],
#  ['BaCO3', 'Nd2O3', 'Mn3O4'],
#  ['Mn(OH)2', 'Nd(OH)3', 'Ba(OH)2'],
#  ['BaCO3', 'MnCO3', 'Nd2O3', 'Y2O3'],
#  ['LiCO3', 'SnO2'],
#  ['SnCl4', 'LiH'],
#  ['Li2SO4', 'SnO'],
#  ['Sn(OH)2', 'LiNO3'],
#  ['BaCO3', 'NaSbO3'],
#  ['NaSbO3', 'BaCl2'],
#  ['BaCO3', 'Li2CO3', 'NaSbO3'],
#  ['Ba(NO3)2', 'NaSbO3'],
#  ['TiO2', 'SrCO3'],
#  ['TiN', 'Sr(NO3)2'],
#  ['Sr(OH)2', 'Ti(OH)4'],
#  ['SrCl2', 'TiCl4'],
#  ['MnCO3', 'LiH'],
#  ['Li2CO3', 'Mn3O4'],
#  ['Mn(NO3)2', 'LiNO3'],
#  ['Mn(OH)2', 'LiOH'],
#  ['NaNO3', 'NH4H2PO4'],
#  ['NaPO3', 'V2O5'],
#  ['Na2CO3', 'VOPO4'],
#  ['V2P2O7', 'NaOH'],
#  ['Al2O3', 'SrCO3'],
#  ['Sr(OH)2', 'Al(NO3)3'],
#  ['Al2O3Cl2', 'SrCl2'],
#  ['Al2O3', 'Sr(NO3)2'],
#  ['Al2O3', 'SrCO3'],
#  ['Sr(OH)2', 'Al(NO3)3'],
#  ['AlON', 'Sr(NO3)2'],
#  ['Al2O3', 'SrCO3'],
#  ['Sr(OH)2', 'Al(NO3)3.9H2O'],
#  ['Al2O3', 'SrCl2'],
#  ['KH2PO4', 'Na2CO3', 'NH4VO3', 'NaF'],
#  ['K2HPO4', 'NaVO3', 'NH4F', 'NaF'],
#  ['NH4F', 'Na4V10O28', 'NaF'],
#  ['NaVO3', 'NH4F', 'K3PO4', 'NaF'],
#  ['Fe(NO3)3.9H2O', 'CuCO3.Cu(OH)2'],
#  ['CuO', 'Fe2O3'],
#  ['Cu(NO3)2.6H2O', 'Fe(OH)3'],
#  ['FeCl3.6H2O', 'Cu(OAc)2.H2O'],
#  ['Sr(OH)', 'La(OH)'],
#  ['BiCl3', 'CaCO3', 'CaCl2', 'NaCl'],
#  ['Bi2O3', 'Ca(NO3)2', 'NaCl'],
#  ['BiCl3', 'Ca(OH)2', 'NaOH', 'HCl'],
#  ['CaO', 'Bi2O3', 'HCl', 'NaCl'],
#  ['Co(NO3)2', 'MnCO3', 'K2CO3'],
#  ['Co(OH)2', 'Mn3O4'],
#  ['Mn(Ac)2', 'Co(Ac)2'],
#  ['MnCO3', 'Co(OH)2', 'Y2O3'],
#  ['SnO', 'Nb2O5', 'Y2O3'],
#  ['Na2CO3', 'SnCl4', 'NbCl5'],
#  ['K2CO3', 'Nb(OH)3', 'Sn(NO3)2'],
#  ['Li2CO3', 'SnO2', 'Nb2O5'],
#  ['Fe(NO3)3.9H2O', 'CuCO3.Cu(OH)2'],
#  ['CuO', 'Fe2O3'],
#  ['Cu(NO3)2.6H2O', 'Fe(OH)3'],
#  ['FeCl3.6H2O', 'Cu(OAc)2.H2O'],
#  ['AgNO3', 'Sb2O3'],
#  ['Sb2O5', 'Ag2CO3'],
#  ['Ag2O', 'Sb2O3'],
#  ['AgCl', 'K2CO3', 'Sb2OCl5'],
#  ['TiO2', 'K2CO3'],
#  ['Ti(OH)4', 'KOH'],
#  ['Ti(OC(CH3)3)4', 'KOH'],
#  ['Ti(OH)4', 'KH2PO4'],
#  ['TiO2', 'K2CO3'],
#  ['Ti(OC(CH3)3)4', 'KOH'],
#  ['Ti(OH)4', 'KH2PO4'],
#  ['K2CO3', 'TiCl4'],
#  ['TiO2', 'K2CO3'],
#  ['KHF2', 'TiCl4'],
#  ['Ti(OH)4', 'K2SiF6'],
#  ['K2TiF6', 'H2O'],
#  ['TiO2', 'K2CO3'],
#  ['Ti(OH)4', 'KOH'],
#  ['K2CO3', 'TiCl4'],
#  ['KHF2', 'TiO2'],
#  ['Mn3O4', 'MgCO3', 'BaCO3', 'MnCO3', 'La(NO3)3'],
#  ['BaCO3', 'MnCO3', 'MgO', 'La2O3'],
#  ['Mg(OH)2', 'La(OH)3', 'Mn(OH)2', 'Ba(OH)2'],
#  ['Mn3O4', 'Mn(NO3)2', 'Ba(NO3)2', 'Mg(NO3)2', 'La(NO3)3'],
#  ['La(NO3)3', 'MoO3'],
#  ['MoO3', 'La2O3'],
#  ['SiO2', 'LiH'],
#  ['Li2CO3', 'SiO2'],
#  ['Si', 'LiNO3'],
#  ['Li2CO3', 'Li2SiO3'],
#  ['WO3', 'Zn(NO3)2.6H2O'],
#  ['WO3', 'ZnCO3'],
#  ['WO3', 'Zn(OH)2'],
#  ['Na2WO4.2H2O', 'ZnCl2'],
#  ['TiO2', 'LiCO3'],
#  ['LiH', 'TiCl4'],
#  ['Li2SO4', 'TiO2'],
#  ['Ti(OH)4', 'LiNO3'],
#  ['WO3', 'Nd2O3', 'LiCO3', 'LiNO3'],
#  ['WO3', 'Nd2WO6', 'Nd2O3', 'Li2O'],
#  ['WO3', 'Li2CO3', 'Nd(NO3)3', 'LiNO3'],
#  ['WO3', 'Nd(OH)3', 'LiOH', 'LiNO3'],
#  ['Sr(OH)', 'La(OH)'],
#  ['MnCO3', 'LiH'],
#  ['Li2CO3', 'Mn3O4'],
#  ['Mn(NO3)2', 'LiNO3'],
#  ['Mn(OH)2', 'LiOH'],
#  ['LiCO3', 'Mn3O4'],
#  ['Mn(NO3)2', 'LiOH'],
#  ['Mn2O3', 'Li2CO3'],
#  ['MnCO3', 'LiNO3'],
#  ['ZrO2', 'Y2O3', 'CeO2', 'BaCO3'],
#  ['ZrOCl2', 'Y(NO3)3', 'Ce(NO3)3', 'Ba(NO3)2'],
#  ['Ce(OH)3', 'Ba(OH)2', 'Y(OH)3', 'ZrO2'],
#  ['Y(CH3COO)3', 'Ce(CH3COO)3', 'Zr(OC(CH3)3)4', 'Ba(CH3COO)2'],
#  ['FeAs', 'As2O3', 'Cs2CO3', 'Eu2O3'],
#  ['FeAs', 'Cs2CO3', 'Eu(NO3)3', 'As2O5'],
#  ['As2O3', 'Cs2CO3', 'Eu(NO3)3', 'Fe(NO3)3'],
#  ...]

# %%
res = list(set(tuple(sorted(sub)) for sub in data))

# %%
len(data)
# Out:
# 27107

# %%
len(res)
# Out:
# 10905

# %%
with open("data/cleaned_candidates.json", 'w') as json_file:
    json.dump(data, json_file, indent=4)
